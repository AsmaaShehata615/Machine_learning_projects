# %% [markdown]
# ##**Importing packages**

# %%
#importing packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy as stats
import seaborn as sns 

# %matplotlib inline

# %% [markdown]
# Preprocessing

# %%
data = pd.read_csv('/content/multiTimeline.csv', skiprows= 2)

# %%
data
# Out:
#         date  diet  gym  finance
# 0    2004-01   100   31       47
# 1    2004-02    78   26       49
# 2    2004-03    67   25       47
# 3    2004-04    70   23       46
# 4    2004-05    73   22       45
# ..       ...   ...  ...      ...
# 210  2021-07    34   48       55
# 211  2021-08    33   48       56
# 212  2021-09    33   48       57
# 213  2021-10    32   43       56
# 214  2021-11    31   45       65
#
# [215 rows x 4 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     215 non-null    object
#  1   diet     215 non-null    int64
#  2   gym      215 non-null    int64
#  3   finance  215 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 6.8+ KB

# %%
data.describe()
# Out:
#              diet         gym     finance
# count  215.000000  215.000000  215.000000
# mean    49.344186   38.227907   49.344186
# std      8.601383    9.415098    6.144875
# min     31.000000   22.000000   39.000000
# 25%     44.000000   30.000000   45.000000
# 50%     49.000000   38.000000   48.000000
# 75%     54.000000   46.000000   52.000000
# max    100.000000   63.000000   77.000000

# %%
data['date']= pd.to_datetime(data['date'])

# %%
data.set_index('date', inplace=True)

# %%
data.head()
# Out:
#             diet  gym  finance
# date
# 2004-01-01   100   31       47
# 2004-02-01    78   26       49
# 2004-03-01    67   25       47
# 2004-04-01    70   23       46
# 2004-05-01    73   22       45

# %% [markdown]
# ## EDA

# %%
data.plot(figsize=(20, 10))

# %%
data['diet'].plot(figsize=(20, 10))

# %% [markdown]
# ### **trends and seasonality in time series data**
#
# by using rolling avarage

# %%
#converting seasonality data to trend
data['diet'].rolling(12).mean().plot()

# %%
data['gym'].plot(figsize=(20,10))

# %%
data['gym'].rolling(12).mean().plot()

# %%
pd.concat([data['diet'].rolling(12).mean(),data['gym'].rolling(12).mean()],axis=1).plot(figsize=(20,10))

# %% [markdown]
# ##*build a module*
